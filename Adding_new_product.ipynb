# %%
import json

Entry=True
while(Entry):
    fd=open('prodlist.json','r')
    r=fd.read()
    fd.close()
    record=json.loads(r)

    print("Press: 0  for Showing All Data.\n")
    print("Press: 1 for Add product.\n")
    print("Press: 2 for Update\n")
    print("Press: 3 for Delete.\n")
    print("Press: 4  for Exit.\n")
    x=int(input(""))
    if(x==0):
        print("******"*15)
        print("\tProduct_id\tProduct_name\tProduct_Quantity\tPrice")
        print("******"*15)
        for i in record.keys():
            print(f"\t{i}\t\t{record[i]['product_name']}\t\t{record[i]['product_quantity']}\t\t{record[i]['product_price']}\n")
    if(x==1):
        y=True
        while(y):
            found=False
            pro_id=input("Enter Product Id: ")
            for i in record.keys():
                if(i==pro_id):
                    print(f"product Id {pro_id} is already pressent\n")
                    print("Please Enter a new Id :")
                    found=True
            if(found):
                continue;
            else:
                pro_name=input("Enter Product Name:- ")
                pro_quantity=int(input("Enter Number of Quantity of product:- "))
                pro_price=int(input("Enter price of each product:- "))

                record[pro_id]={'product_name':pro_name,'product_quantity':pro_quantity,'product_price':pro_price}

                js = json.dumps(record)
                fd = open("prodlist.json",'w')
                fd.write(js)
                fd.close()
                print("******Your Product Add Success Fully******")
                y=False
    elif(x==2):
        y=True
        while(y):
            found=False
            pro_id=input("Enter Product Id: ")
            for i in record.keys():
                if(i==pro_id):
                    pro_name=input("Enter Product Name:- ")
                    pro_quantity=int(input("Enter Number of Quantity of product:- "))
                    pro_price=int(input("Enter price of each product:- "))
                    record[pro_id]={'product_name':pro_name,'product_quantity':pro_quantity,'product_price':pro_price}
                    js = json.dumps(record)
                    fd = open("prodlist.json",'w')
                    fd.write(js)
                    fd.close()
                    print("******Your Product Update Success Fully******")
                    found=True
                    y=False
            if(found):
                continue;
            else:
                print(f"product Id {pro_id} is Not pressent\n")
                print("Please Re-enter Product Id:")
    elif(x==3):
        y=True
        while(y):
            found=False
            pro_id=input("Enter Product Id: ")
            for i in record.keys():
                if(i==pro_id):
                    found=True
                    y=False
            if(found):
                del record[pro_id]
                js = json.dumps(record)
                fd = open("prodlist.json",'w')
                fd.write(js)
                fd.close()
                print("******Delete Success Fully******")
                continue;
            else:
                print(f"product Id {pro_id} is Not pressent\n")
                print("Please Re-enter Product Id:")
    elif(x==4):
        Entry=False
# Out:
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 2
# Enter Product Id: 1
# Enter Product Name:- blue pen
# Enter Number of Quantity of product:- 380
# Enter price of each product:- 10
# ******Your Product Update Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 1
# Enter Product Id: 2
# product Id 2 is already pressent
#
# Please Enter a new Id :
# Enter Product Id: 3
# product Id 3 is already pressent
#
# Please Enter a new Id :
# Enter Product Id: 31
# Enter Product Name:- ball
# Enter Number of Quantity of product:- 82
# Enter price of each product:- 63
# ******Your Product Add Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 2
# Enter Product Id: 2
# Enter Product Name:- black pen
# Enter Number of Quantity of product:- 350
# Enter price of each product:- 10
# ******Your Product Update Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 2
# Enter Product Id: 3
# Enter Product Name:- red pen
# Enter Number of Quantity of product:- 200
# Enter price of each product:- 15
# ******Your Product Update Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 2
# Enter Product Id: 4
# Enter Product Name:- green pen
# Enter Number of Quantity of product:- 200
# Enter price of each product:- 15
# ******Your Product Update Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 2
# Enter Product Id: 5
# Enter Product Name:- pen holder
# Enter Number of Quantity of product:- 15
# Enter price of each product:- 52
# ******Your Product Update Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 2
# Enter Product Id: 6
# Enter Product Name:- pencil
# Enter Number of Quantity of product:- 100
# Enter price of each product:- 5
# ******Your Product Update Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 2
# Enter Product Id: 7
# Enter Product Name:- eraser
# Enter Number of Quantity of product:- 100
# Enter price of each product:- 5
# ******Your Product Update Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 2
# Enter Product Id: 8
# Enter Product Name:- copy
# Enter Number of Quantity of product:- 200
# Enter price of each product:- 25
# ******Your Product Update Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 2
# Enter Product Id: 9
# Enter Product Name:- register
# Enter Number of Quantity of product:- 100
# Enter price of each product:- 100
# ******Your Product Update Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 2
# Enter Product Id: 10
# Enter Product Name:- paper cutter
# Enter Number of Quantity of product:- 95
# Enter price of each product:- 11
# ******Your Product Update Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 2
# Enter Product Id: 11
# Enter Product Name:- paper pin
# Enter Number of Quantity of product:- 200
# Enter price of each product:- 2
# ******Your Product Update Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 2
# Enter Product Id: 12
# Enter Product Name:- paper clip
# Enter Number of Quantity of product:- 200
# Enter price of each product:- 8
# ******Your Product Update Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 2
# Enter Product Id: 13
# Enter Product Name:- paper (A4 size)
# Enter Number of Quantity of product:- 50
# Enter price of each product:- 250
# ******Your Product Update Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 2
# Enter Product Id: 13
# Enter Product Name:- paper(A4 size)
# Enter Number of Quantity of product:- 50
# Enter price of each product:- 250
# ******Your Product Update Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 2
# Enter Product Id: 14
# Enter Product Name:- gematry box
# Enter Number of Quantity of product:- 50
# Enter price of each product:- 45
# ******Your Product Update Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 2
# Enter Product Id: 15
# Enter Product Name:- water color
# Enter Number of Quantity of product:- 25
# Enter price of each product:- 80
# ******Your Product Update Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 2
# Enter Product Id: 16
# Enter Product Name:- pencil color
# Enter Number of Quantity of product:- 25
# Enter price of each product:- 65
# ******Your Product Update Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 2
# Enter Product Id: 17
# Enter Product Name:- glue
# Enter Number of Quantity of product:- 20
# Enter price of each product:- 10
# ******Your Product Update Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 2
# Enter Product Id: 18
# Enter Product Name:- sticky tapes
# Enter Number of Quantity of product:- 20
# Enter price of each product:- 100
# ******Your Product Update Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 2
# Enter Product Id: 19
# Enter Product Name:- highlight pen
# Enter Number of Quantity of product:- 80
# Enter price of each product:- 20
# ******Your Product Update Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 2
# Enter Product Id: 20
# Enter Product Name:- note holder
# Enter Number of Quantity of product:- 70
# Enter price of each product:- 50
# ******Your Product Update Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 2
# Enter Product Id: calculator
# product Id calculator is Not pressent
#
# Please Re-enter Product Id:
# Enter Product Id: 20
# Enter Product Name:- 250
# Enter Number of Quantity of product:- 1
# Enter price of each product:- 2
# ******Your Product Update Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 2
# Enter Product Id: 20
# Enter Product Name:- note holder
# Enter Number of Quantity of product:- 70
# Enter price of each product:- 50
# ******Your Product Update Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 2
# Enter Product Id: 21
# Enter Product Name:- caculater
# Enter Number of Quantity of product:- 20
# Enter price of each product:- 250
# ******Your Product Update Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 2
# Enter Product Id: 22
# Enter Product Name:- stapler
# Enter Number of Quantity of product:- 70
# Enter price of each product:- 25
# ******Your Product Update Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 2
# Enter Product Id: 23
# Enter Product Name:- table lamp
# Enter Number of Quantity of product:- 15
# Enter price of each product:- 856
# ******Your Product Update Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 2
# Enter Product Id: 24
# Enter Product Name:- panching machine
# Enter Number of Quantity of product:- 20
# Enter price of each product:- 50
# ******Your Product Update Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 2
# Enter Product Id: 25
# Enter Product Name:- water bottle
# Enter Number of Quantity of product:- 1
# Enter price of each product:- 1
# ******Your Product Update Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 2
# Enter Product Id: 25
# Enter Product Name:- water bottle(500ml)
# Enter Number of Quantity of product:- 25
# Enter price of each product:- 580
# ******Your Product Update Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 2
# Enter Product Id: 26
# Enter Product Name:- water bottle
# Enter Number of Quantity of product:- 1
# Enter price of each product:- 1
# ******Your Product Update Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 2
# Enter Product Id: 26
# Enter Product Name:- water bottle(1000ml)
# Enter Number of Quantity of product:- 25
# Enter price of each product:- 1005
# ******Your Product Update Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 2
# Enter Product Id: 27
# Enter Product Name:- bat
# Enter Number of Quantity of product:- 28
# Enter price of each product:- 230
# ******Your Product Update Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 2
# Enter Product Id: 28
# Enter Product Name:- football
# Enter Number of Quantity of product:- 41
# Enter price of each product:- 652
# ******Your Product Update Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 2
# Enter Product Id: 29
# Enter Product Name:- basketball
# Enter Number of Quantity of product:- 35
# Enter price of each product:- 789
# ******Your Product Update Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 0
# ******************************************************************************************
# 	Product_id	Product_name	Product_Quantity	Price
# ******************************************************************************************
# 	1		blue pen		380		10
#
# 	2		black pen		350		10
#
# 	3		red pen		200		15
#
# 	4		green pen		200		15
#
# 	5		pen holder		15		52
#
# 	6		pencil		100		5
#
# 	7		eraser		100		5
#
# 	8		copy		200		25
#
# 	9		register		100		100
#
# 	10		paper cutter		95		11
#
# 	11		paper pin		200		2
#
# 	12		paper clip		200		8
#
# 	13		paper(A4 size)		50		250
#
# 	14		gematry box		50		45
#
# 	15		water color		25		80
#
# 	16		pencil color		25		65
#
# 	17		glue		20		10
#
# 	18		sticky tapes		20		100
#
# 	19		highlight pen		80		20
#
# 	20		note holder		70		50
#
# 	21		caculater		20		250
#
# 	22		stapler		70		25
#
# 	23		table lamp		15		856
#
# 	24		panching machine		20		50
#
# 	25		water bottle(500ml)		25		580
#
# 	26		water bottle(1000ml)		25		1005
#
# 	27		bat		28		230
#
# 	28		football		41		652
#
# 	29		basketball		35		789
#
# 	30		Fevecool 10ml		50		13
#
# 	31		ball		82		63
#
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 3
# Enter Product Id: 31
# ******Delete Success Fully******
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.
#
# 0
# ******************************************************************************************
# 	Product_id	Product_name	Product_Quantity	Price
# ******************************************************************************************
# 	1		blue pen		380		10
#
# 	2		black pen		350		10
#
# 	3		red pen		200		15
#
# 	4		green pen		200		15
#
# 	5		pen holder		15		52
#
# 	6		pencil		100		5
#
# 	7		eraser		100		5
#
# 	8		copy		200		25
#
# 	9		register		100		100
#
# 	10		paper cutter		95		11
#
# 	11		paper pin		200		2
#
# 	12		paper clip		200		8
#
# 	13		paper(A4 size)		50		250
#
# 	14		gematry box		50		45
#
# 	15		water color		25		80
#
# 	16		pencil color		25		65
#
# 	17		glue		20		10
#
# 	18		sticky tapes		20		100
#
# 	19		highlight pen		80		20
#
# 	20		note holder		70		50
#
# 	21		caculater		20		250
#
# 	22		stapler		70		25
#
# 	23		table lamp		15		856
#
# 	24		panching machine		20		50
#
# 	25		water bottle(500ml)		25		580
#
# 	26		water bottle(1000ml)		25		1005
#
# 	27		bat		28		230
#
# 	28		football		41		652
#
# 	29		basketball		35		789
#
# 	30		Fevecool 10ml		50		13
#
# Press: 0  for Showing All Data.
#
# Press: 1 for Add product.
#
# Press: 2 for Update
#
# Press: 3 for Delete.
#
# Press: 4  for Exit.

# %%
'''import json

fd=open('prodlist.json','r')
r=fd.read()
record=json.loads(r)
print(len(record))
fd.close()'''
